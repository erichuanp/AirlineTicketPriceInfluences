# %% [markdown]
# # Fly High: The Influence of Precipitation and Fuel Consumption on Plane Ticket Prices
# ## COGS 108 - Final Project

# %% [markdown]
# # Permissions
#
# Place an `X` in the appropriate bracket below to specify if you would like your group's project to be made available to the public. (Note that student names will be included (but PIDs will be scraped from any groups who include their PIDs).
#
# * [X] YES - make available
# * [ ] NO - keep private

# %% [markdown]
# # Names
#
# - Kunnam Kim
# - Maya Buchwald
# - Risa Sundu
# - Jaeven Tanuwidjaja
# - Chuan Peng

# %% [markdown]
# # Abstract
#
# In this study, we examined the relationships between average monthly precipitation, fuel consumption, and ticket prices in the U.S. commercial aviation sector over the past decade. Using datasets from NOAA, the U.S. Department of Transportation, and the Bureau of Transportation Statistics, we sought to understand how weather conditions influence fuel efficiency and pricing strategies in the aviation industry.
#
# Our analysis revealed a weak positive correlation between precipitation and fuel consumption, suggesting other factors predominantly influence fuel usage. The relationship between fuel consumption and ticket prices was complex, with notable variations pre- and post-2020, likely impacted by the COVID-19 pandemic. These findings underscore the multifaceted nature of operational and pricing strategies in aviation, highlighting the need for comprehensive approaches to improve fuel efficiency and cost-effectiveness in the industry.

# %% [markdown]
# # Research Question

# %% [markdown]
# -  Is there a relationship between average monthly precipitation levels and average monthly commercial aircraft fuel consumption in the last 10 years in the United States?
# -  Is there a relationship between average flight fuel consumption and average ticket price for commercial aircraft in the last 10 years in the United States?

# %% [markdown]
# ## Background and Prior Work

# %% [markdown]
# In a globalizing world, air travel has become increasingly important not only for economic purposes, but for individual purposes as well. However, since the early 2000s, fuel prices have continued to increase, making it ever more important to optimize fuel efficiency. Consumers are increasingly concerned about their carbon footprint when they fly, and some airlines are offering dubious, albeit optional, carbon offset add-ons to their tickets.<a name="cite_ref-2"></a>[<sup>2</sup>](#cite_note-2) Not only do CO2 emissions from commercial flights contribute to air pollution, but ticket costs are also affected by fuel prices and consumption rates.
#
#
# According to an article by the firm McKinsey & Company, between 2005 and 2019 airlines managed to decrease fuel per passenger-kilometer by 39%.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Roughly half of this decrease owes itself to an increase in seat density and percentage of seats per flight sold. Airlines increased the number of passengers per plane by 82% in 2005 and by 88% in 2019.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) Next, fleet upgrades account for a little less than half of this decrease in fuel per passenger-kilometer.<a name="cite_ref-1"></a>[<sup>1</sup>](#cite_note-1) As aircrafts have become more aerodynamic, they’ve become more fuel efficient as well. Other factors like route optimization accounts for less than 7% of the improved fuel mileage. As technological advancements slow down, airlines inevitably have begun to hit a plateau in improving fuel efficiency. Likewise, increasing aircraft density can only go so far.
#
# Similarly, the paper *Fuel consumption optimization in air transport* by Singh and Sharma examines historical trends of fuel consumption optimization (FCO). They identify four factors that affect fuel consumption: aircraft technology & design, aviation operations & infrastructure, socioeconomic & policy measures, and alternate fuels & fuel properties.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) The authors found that “Fuel consumption is one of major direct operating cost parameters in the air transport industry” and accounts for roughly 28% of operating costs, but in the future it may account for as much as 45%.<a name="cite_ref-4"></a>[<sup>4</sup>](#cite_note-4) Similar to the findings of McKinsey, while jet fuel has increased significantly since 2005, fuel efficiency improvements have slowed down since the 1980s. Airline route optimization is incredibly complex, bringing together diverse factors such as aircraft performance, weather, route and regulatory restrictions, luggage and passenger capacity, and global fuel and travel economics.<a name="cite_ref-3"></a>[<sup>3</sup>](#cite_note-3) For the scope of our project, we will be focusing mainly on the relationship between cabin density and fuel consumption per passenger-kilometer. We hope to understand how external factors such as weather also play into fuel consumption and subsequently ticket prices. We hope to study precipitation levels in origin and destination airports, fuel consumption, and ticket prices of those flights. Our goal is to determine whether future aircraft manufacturing efforts should aim to make airplanes more adaptable to poor weather conditions by determining if weather is a factor affecting fuel consumption.
#
#
# 1. <a name="cite_note-1"></a> [^](#cite_ref-1) Esqué, A. (2022, March 1) Fuel efficiency: Why airlines need to switch to more ambitious measures. *McKinsey & Company*. https://www.mckinsey.com/industries/aerospace-and-defense/our-insights/future-air-mobility-blog/fuel-efficiency-why-airlines-need-to-switch-to-more-ambitious-measures
#
# 2. <a name="cite_note-2"></a> [^](#cite_ref-2) Jockims, T. L. (2022, December 19) When searching for a flight, be wary of offers to add your climate impact to the ticket price. *CNBC*. https://www.cnbc.com/2022/12/17/airlines-can-price-climate-change-into-a-plane-ticket-dont-buy-it.html
#
# 3. <a name="cite_note-3"></a> [^](#cite_ref-3) Kousik, N. V. (2019) Flight plan route optimization and increase the profit in airline industry by using hybrid BCF algorithm. *ICTACT Journal on Communication Technology*. https://ictactjournals.in/paper/IJCT_Vol_10_Iss_3_Paper_1_2019_2023.pdf
#
# 4. <a name="cite_note-4"></a> [^](#cite_ref-4) Singh, V., Sharma, S.K. (2015) Fuel consumption optimization in air transport: a review, classification, critique, simple meta-analysis, and future researchimpl ications.*European Transport Research Review, 7*(12). https://doi.org/10.1007/s12544-015-0160-x

# %% [markdown]
# # Hypothesis

# %% [markdown]
# Experience suggests that very increased precipitation leads to more frequent encounters with unstable air currents for aircraft, necessitating changes in flight altitude and routes, but small amounts of precipitation probably have little impact on flight routes. This likely results in underestimations of optimal fuel consumption and higher actual fuel usage in extreme weather. To offset the additional operational costs, airlines are expected to raise ticket prices when weather is less predictable (such as in the winter) and fuel consumption is high.

# %% [markdown]
# # Data

# %% [markdown]
# ## Data overview
#
# - Dataset #1
#   - Dataset Name: Airline Fuel Cost and Consumption (U.S. Carriers - Scheduled)
#   - Link to the dataset: https://www.transtats.bts.gov/fuel.asp?20=D&qv52ynB=qn6nE
#   - Number of observations: 120
#   - Number of variables: 5
# - Dataset #2
#   - Dataset Name: National-Level Domestic Average Fare Series
#   - Link to the dataset: https://www.bts.gov/content/national-level-domestic-average-fare-series
#   - Number of observations: 39
#   - Number of variables: 4
# - Dataset #3
#   - Dataset Name: Contiguous U.S. Precipitation
#   - Link to the dataset: https://www.ncei.noaa.gov/access/monitoring/climate-at-a-glance/national/time-series/110/pcp/1/0/2000-2024?base_prd=true&begbaseyear=1901&endbaseyear=2000
#   - Number of observations: 120
#   - Number of variables: 4
#
# Dataset #1: This dataset includes monthly data from Jan 2000 - Dec 2023 on how much fuel cost per gallon at the time and how many total gallons of fuel were consumed that month. It has data for domestic flights, international flights, and the total of the two. Using this data, we can examine the relationship between average fuel consumption and average precipitation in the U.S. on any given month. The year and month data are objects/strings while the consumption and cost columns are floats.
#
# Dataset #2: This dataset describes the average airline fare of domestic flights in the U.S. each quarter from 1995 to 2023. It also includes an inflation-adjusted price amount. Because we couldn't find monthly fare data, we may need to compare by quarter with average fuel consumption during the corresponding months. This will require combining (averaging) the months that correspond with each quarter in the other two datasets to make a comparable time range for our analysis. The year and quarter data are objects/strings while the price columns are floats.
#
# Dataset #3: This dataset gives us average precipitation across the contiguous U.S. in inches by month. Data is available beginning in 1895, but for our analysis we will only look at the past 10 years. The year and month data are objects/strings while the precipitation and anomaly columns are floats.
#
# We will use Dataset #3 and #1 to analyze the first part of our research question, which is concerned with the relationship between average precipitation and average fuel consumption. Datasets #2 and #1 will help us address the second part of our question, which involves the relationship between fuel consumption and ticket prices of domestic U.S. commercial flights.

# %%
# here are imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Dataset #1 Airline Fuel Cost and Consumption

# %%
# clean the dataset
dataset1 = pd.read_csv('Datasets/dataset1.csv')
dataset1 = dataset1[(dataset1['Year'] >= '2014') & (dataset1['Year'] <= '2023')]  # limit to ten years 2014-2023
dataset1 = dataset1[~((dataset1['Month'].str.lower() == 'total') | (dataset1['Year'].str.contains('% Chg over')))]  # delete rows that are not monthly
dataset1['Month'] = dataset1['Month'].str.strip().apply(lambda x: {'January': '1', 'February': '2', 'March': '3', 'April': '4', 'May': '5', 'June': '6', 'July': '7', 'August': '8', 'September': '9', 'October': '10', 'November': '11', 'December': '12'}.get(x, None))  # convert months to number-months
dataset1['Year_Month'] = dataset1['Year'] + '-' + dataset1['Month']  # for x-axis

# for standardizing dates 
dataset1['Year_Month'] = pd.to_datetime(dataset1['Year_Month'])

# %%
# Monthly Consumption of Fuel Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset1['Year_Month'], dataset1['Consumption(million gallons)'], marker='o', linestyle='-', color='blue')
plt.title('Monthly Consumption of Fuel Over Time (2014-2023)')
plt.xlabel('Month')
plt.ylabel('Fuel Consumption (million gallons)')
plt.tight_layout()

plt.show()

# %%
# Monthly Fuel Cost Over Time (2014-2023
plt.figure(figsize=(20, 8))
plt.plot(dataset1['Year_Month'], dataset1['Cost(million dollars)'], marker='o', linestyle='-', color='red')
plt.title('Monthly Fuel Cost Over Time (2014-2023)')
plt.xlabel('Month')
plt.ylabel('Fuel Cost (million dollars)')
plt.tight_layout()

plt.show()

# %%
# Monthly Fuel Cost per Gallon Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset1['Year_Month'], dataset1['Cost per Gallon (dollars)'], marker='o', linestyle='-', color='green')
plt.title('Monthly Fuel Cost per Gallon Over Time (2014-2023)')
plt.xlabel('Month')
plt.ylabel('Fuel Cost per Gallon (dollars)')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Dataset #2 National-Level Domestic Average Fare Series

# %%
# clean the dataset
dataset2 = pd.read_csv('Datasets/dataset2.csv')
dataset2['Year'] = dataset2['Year'].astype(str)  # convert years to strings
dataset2['Quarter'] = dataset2['Quarter'].astype(str)  # convert quarters to strings
dataset2 = dataset2[(dataset2['Year'] >= '2014') & (dataset2['Year'] <= '2023')]  # limit to ten years 2014-2023
dataset2['Year_Quarter'] = dataset2['Year'] + '-Q' + dataset2['Quarter']  # for x-axis

# %%
# U.S. Average Ticket Price: Current vs. Inflation-Adjusted ($) Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset2['Year_Quarter'], dataset2['U.S. Average (Current $) '], marker='o', linestyle='-', color='purple', label='U.S. Average (Current $)')
plt.plot(dataset2['Year_Quarter'], dataset2['U.S. Average (Inflation-Adjusted $) '], marker='o', linestyle='-', color='skyblue', label='U.S. Average (Inflation-Adjusted $)')
plt.title('U.S. Average Ticket Price: Current vs. Inflation-Adjusted ($) Over Time (2014-2023)')
plt.xlabel('Quarter')
plt.ylabel('Ticket Price (Dollars)')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Dataset #3 Contiguous U.S. Precipitation

# %%
# clean the dataset
dataset3 = pd.read_csv('Datasets/dataset3.csv')
dataset3['Year'] = dataset3['Year'].astype(str)  # convert years to strings
dataset3['Month'] = dataset3['Month'].astype(str)  # convert months to strings
dataset3 = dataset3[(dataset3['Year'] >= '2014') & (dataset3['Year'] <= '2023')]  # limit to ten years 2014-2023
dataset3['Year_Month'] = dataset3['Year'] + '-' + dataset3['Month'].str.pad(2, fillchar='0')  # for x-axis

# for standardizing dates (later)
# dataset3['Year_Month'] = pd.to_datetime(dataset3['Year_Month'])

# %%
# Average Precipitation Value Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset3['Year_Month'], dataset3['Value'], marker='o', linestyle='-', color='darkorange', label='Value')
plt.title('Monthly Average U.S. Precipitation Over Time (2014-2023)')
plt.xlabel('Month')
plt.ylabel('Average Precipitation (inches)')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.show()

# %%
# Precipitation Anomaly Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset3['Year_Month'], dataset3['Anomaly'], marker='o', linestyle='-', color='teal', label='Anomaly')
plt.title('Precipitation Anomaly Over Time (2014-2023)')
plt.xlabel('Year-Month')
plt.ylabel('Anomaly')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.show()

# %% [markdown]
# # Results

# %% [markdown]
# Before answering our questions, we performed exploratory data analysis on each of our datasets to make sure we understood trends within each one.
#
# First, we wanted to fully understand what data was available in the cleaned dataset and view the general distribution of each.

# %% [markdown]
# ## Dataset 1: Fuel cost & consumption

# %%
# Average monthly fuel cost & consumption data
display(dataset1.head()) # what do the columns look like
display(dataset1.describe()) # what are typical values for the numeric columns
# Out:
#      Year Month  Consumption(million gallons)  Cost(million dollars)  \
# 195  2014     1                         793.7                 2453.9
# 196  2014     2                         737.8                 2246.3
# 197  2014     3                         882.6                 2651.2
# 198  2014     4                         851.1                 2536.1
# 199  2014     5                         874.0                 2612.6
#
#      Cost per Gallon (dollars) Year_Month
# 195                       3.09 2014-01-01
# 196                       3.04 2014-02-01
# 197                       3.00 2014-03-01
# 198                       2.98 2014-04-01
# 199                       2.99 2014-05-01
#        Consumption(million gallons)  Cost(million dollars)  \
# count                    120.000000             120.000000
# mean                     904.975833            1987.898333
# min                      297.000000             316.300000
# ...

# %% [markdown]
# In the U.S. between 2014 and 2023, for commercial airline flights:
# * The median monthly consumption of fuel was 945 million gallons.
# * The median total monthly expenditure on fuel was $1,926,000,000.
# * The median cost of fuel per gallon was $2.00.
#
# All three variables have pretty significant standard deviations.
# * Monthly fuel consumption: 154.2 million gallons
# * Total expenditure: 761.09 million dollars
# * Cost per gallon: $0.68

# %%
plt.figure(figsize=(8,2))
sns.boxplot(x=dataset1['Consumption(million gallons)']);
plt.title('Distribution of Monthly Fuel Consumption by Domestic U.S. Flights 2014-2023');
plt.show()

# %% [markdown]
# This visualization of the distribution of monthly fuel consumption by U.S. domestic flights shows how during most of the months, flights consumed between 700 and 1,100 million gallons, but there are many outliers that are less than that. As a result, the data is left-skewed, with the mean being lower than the median of fuel consumption. The presence of outliers in the data could be due to factors such as size of the airline's airplanes, the frequency of their flights, and the popularity of the airline.

# %%
plt.figure(figsize=(8,2))
sns.boxplot(x=dataset1['Cost per Gallon (dollars)']);
plt.title('Distribution of Airline Fuel Price per Gallon 2014-2023');
plt.show()

# %% [markdown]
# This box plot of average fuel price shows that for the majority of the months, fuel cost between $1.00 and $3.90, with only 1 outlier around $4.00. As opposed to monthly fuel consumption by domestic flights, there is far fewer outliers. However, the data is right skewed. This skew in the data oculd potentially be to sharp increases in fuel price per gallon during cyclical sharp increases in demand or falls in supply.

# %% [markdown]
# We noticed a predictable pattern in the fuel consumption data year over year, so we look to see whether significant dates have a relationship with fuel consumption. We specifically checked how fuel consumption changed around the 4th of July and New Year's Day.

# %%
# define the significant dates
newyear_date = '01-01'
independence_date = '07-04'
covid_date = pd.to_datetime('03-01-2020')

# generate holiday dates for each year from 2014 to 2023
newyear = pd.to_datetime([f'{year}-{newyear_date}' for year in range(2014, 2024)])
independence = pd.to_datetime([f'{year}-{independence_date}' for year in range(2014, 2024)])

# generate plot
plt.figure(figsize=(20, 8))
plt.plot(dataset1['Year_Month'], dataset1['Consumption(million gallons)'], marker='o', linestyle='-', color='blue', label='Fuel Consumption')
plt.title('Patterns in U.S. Domestic Airline Monthly Consumption of Fuel Over Time (2014-2023)',size=24)
plt.xlabel('Date')
plt.ylabel('Fuel Consumption (million gallons)')
plt.xticks(rotation=90)

# adding vertical lines for important dates
for newyear_date in newyear:
    plt.axvline(x=newyear_date, color='olive', linestyle='--', linewidth=1)
for independence_date in independence:
    plt.axvline(x=independence_date, color='red', linestyle='--', linewidth=1)

plt.axvline(x=covid_date, color='black',linestyle = '-',linewidth=3)

# add entry for holidays in the legend
plt.legend(['Fuel Consumption','New Year\'s Day','4th of July'])
plt.text(.63,.9,'COVID-19 hits the U.S.',transform=plt.gca().transAxes,fontsize=14)

plt.tight_layout()
plt.show()

# %% [markdown]
# Fuel consumption appears to peak in the summer, around the 4th of July. There is a dip each year sometime a month or so after the new year. Predictably, airline fuel consumption plummeted during the beginning of the pandemic, and slowly rose as the global economy recovered.

# %% [markdown]
# The monthly fuel price graph does not show such a predictable pattern over time, but it also plummeted when the pandemic broke out.

# %%
# Monthly Fuel Cost Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset1['Year_Month'], dataset1['Cost per Gallon (dollars)'], marker='o', linestyle='-', color='red')
plt.title('Average Fuel Price per Gallon (2014-2023)',size=24)
plt.xlabel('Month')
plt.ylabel('Fuel Price (dollars)')
plt.xticks(rotation=90)
plt.tight_layout()

# add COVID-19 date
plt.axvline(x=covid_date, color='black',linestyle = '-',linewidth=3)
plt.text(.63,.9,'COVID-19 hits the U.S.',transform=plt.gca().transAxes,fontsize=14)

plt.show()

# %% [markdown]
# Although it is fair to assume that fuel prices went down while people were staying at home during the pandemic in 2020, it is difficult to identify a cause for the peak towards the end of 2022. Based on preliminary research, this maximum may have been a result of the Russia-Ukraine war, but it is difficult to say for sure.

# %% [markdown]
# ## Dataset 2: Airline fares

# %%
# Average U.S. commercial airline fare data
display(dataset2.head()) # what do the columns look like
dataset2.describe() # what are typical values for the numeric columns
# Out:
#     Year Quarter  U.S. Average (Current $)   \
# 76  2014       1                 387.366657
# 77  2014       2                 402.313502
# 78  2014       3                 399.246496
# 79  2014       4                 395.355155
# 80  2015       1                 390.128124
#
#     U.S. Average (Inflation-Adjusted $)  Year_Quarter
# 76                            505.784950      2014-Q1
# 77                            519.170342      2014-Q2
# 78                            514.622340      2014-Q3
# 79                            513.733551      2014-Q4
# 80                            509.710167      2015-Q1
#        U.S. Average (Current $)   U.S. Average (Inflation-Adjusted $)
# count                  39.000000                             39.000000
# mean                  350.092813                            419.218394
# std                    40.337705                             61.095608
# min                   244.710501                            289.051423
# ...

# %% [markdown]
# Between 2014 and 2023, for U.S. commercial airlines:
#
# * The median price of a domestic flight ticket was $425.35, adjusted for inflation. The data has two outliers and it is very slightly left skewed, close to being a normal distribution. The median is a better average because the mean is affected by some outliers that may be airlines that sell really cheap tickets. Other potential causes could be due to the plummet in price of tickets during the beginning of lockdown.
# * This has a standard deviation of $61.10.

# %%
plt.figure(figsize=(8,2))
sns.boxplot(x=dataset2['U.S. Average (Inflation-Adjusted $) ']);
plt.title('Distribution of Average Commercial Airline Ticket Price for U.S. Domestic Flights, 2014-2023');
plt.show()

# %% [markdown]
# The box plot above shows that the data is centered around the $400-450 range, with prices between $300 and $550 fairly common, and a few outliers below the $300 range.

# %% [markdown]
# The COVID-19 pandemic had a similar effect on airline ticket prices as it did on fuel consumption and price.

# %%
covid_quarter = '2020-Q1' # approximate date of COVID pandemic in financial quarter

plt.figure(figsize=(20, 8))
plt.plot(dataset2['Year_Quarter'], dataset2['U.S. Average (Current $) '], marker='o', linestyle='-', color='purple', label='U.S. Average (Current $)')
plt.plot(dataset2['Year_Quarter'], dataset2['U.S. Average (Inflation-Adjusted $) '], marker='o', linestyle='-', color='skyblue', label='U.S. Average (Inflation-Adjusted $)')
plt.title('U.S. Average Ticket Price: Current vs. Inflation-Adjusted ($) Over Time (2014-2023)')
plt.xlabel('Quarter')
plt.ylabel('Ticket Price (Dollars)')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.axvline(x=covid_quarter, color='black',linestyle = '-',linewidth=3)
plt.text(.64,.9,'COVID-19 hits the U.S.',transform=plt.gca().transAxes,fontsize=14)

plt.show()

# %% [markdown]
# Observing this graph, it is also apparent that ticket price decreased gradually between 2014 and 2017, before plateuing until the pandemic in 2020. Based on visual analysis, it looks like ticket prices have been continuing this decreasing trend since returning to their pre-pandemic price around 2022.

# %% [markdown]
# ## Dataset 3: Precipitation

# %%
# Monthly U.S. precipitation data
display(dataset3.head()) # what do the columns look like
dataset3.describe() # what are typical values for the numeric columns
# Out:
#      Year Month  Value  Anomaly Year_Month
# 168  2014     1   1.37    -0.94    2014-01
# 169  2014     2   2.25     0.12    2014-02
# 170  2014     3   2.37    -0.14    2014-03
# 171  2014     4   2.88     0.36    2014-04
# 172  2014     5   2.81    -0.10    2014-05
#             Value     Anomaly
# count  120.000000  120.000000
# mean     2.644917    0.149917
# std      0.593450    0.514688
# min      1.300000   -0.940000
# 25%      2.250000   -0.200000
# 50%      2.620000    0.115000
# 75%      3.005000    0.440000
# max      4.470000    1.710000

# %% [markdown]
# Between 2014 and 2023, for the contiguous U.S.:
# * The median monthly precipitation was 2.62 inches.
# * This has a standard deviation of 0.59 inches. This shows a normal distribution with a few outliers, likely because of El nino years.

# %%
plt.figure(figsize=(8,2))
sns.boxplot(x=dataset3['Value']);
plt.title('Distribution of Average Monthly Precipitation in the Contiguous U.S. 2014-2023');
plt.xlabel('Inches Precipitation')
plt.show()

# %% [markdown]
# The box plot above illustrates that the data is centered around 2.3-3.0 inches of monthly precipitation, with values between 1.3 and 4.1 fairly common, and two outliers around 4.5 inches. When were those particularly rainy months?

# %%
sorted_df3 = dataset3.sort_values(by='Value',ascending=False)
sorted_df3[:2]
# Out:
#      Year Month  Value  Anomaly Year_Month
# 232  2019     5   4.47     1.56    2019-05
# 184  2015     5   4.44     1.53    2015-05

# %% [markdown]
# May of 2015 and 2019 were the rainiest 2 months in the U.S. in the last 10 years. According to a quick <a href="https://en.wikipedia.org/wiki/El_Ni%C3%B1o%E2%80%93Southern_Oscillation#El_Ni%C3%B1o_phase">search</a>, between 2014 and 2023, 3 El Niño events have occurred:
# * 2014-2016
# * 2018-2019
# * 2023-2024
#
# Given this background, it makes sense that more precipitation would fall in North America during those years than non-El Niño years. It may be valuable to our analysis to identify El Niño years as particularly weather-intensive periods of time.

# %% [markdown]
# It is difficult to identify a pattern in average precipitation data. This may be due to the fact that precipitation across such a large geographical area is simply so variable. Below, we try to determine if there is an obvious seasonal variation by indicating summer months in yellow and winter months in blue.

# %%
# Average U.S. Precipitation Over Time (2014-2023)
plt.figure(figsize=(20, 8))
plt.plot(dataset3['Year_Month'], dataset3['Value'], marker='o', linestyle='-', color='blue', label='Value')
plt.title('Monthly Average U.S. Precipitation Over Time (2014-2023)')
plt.xlabel('Month')
plt.ylabel('Average Precipitation (inches)')
plt.xticks(rotation=90)
plt.legend()

# add color backgrounds for winter and summer
winter_months = ["Dec", "Jan", "Feb"]
summer_months = ["Jun", "Jul", "Aug"]

# loop through each year and shade the winter and summer months
for year in range(2014, 2024):
    winter_start = f"{year}-12"
    winter_end = f"{year + 1}-02"
    summer_start = f"{year}-06"
    summer_end = f"{year}-08"
    
    plt.axvspan(winter_start, winter_end, color='lightblue', alpha=0.3, label='Winter')
    plt.axvspan(summer_start, summer_end, color='gold', alpha=0.6, label='Summer')

# display legend for shading
plt.legend(['Value','Winter','Summer'])

plt.tight_layout()
plt.show()

# %% [markdown]
# It is possible that overall, precipitation increases in the summer months and decreases in the winter months. However, this isn't extremely consistent, at least in the last 10 years. There is no obvious seasonal variation for the precipitation, at least from basic visual analysis from this scale.

# %% [markdown]
# After exploring each of our datasets, we were ready to begin to answer our research questions.

# %% [markdown]
# ## Question Part 1: Precipitation & Fuel Consumption
#
# The first part of our research question asks whether there is a relationship between average precipitation in the U.S. and average fuel consumption in the last 10 years, to see how this type of weather affects fuel efficiency.
#
# We decided to create a heatmap to visualize the correlation between precipitation and fuel consumption in our datasets.

# %%
# Convert 'Year_Month' in dataset3 to datetime format
dataset3['Year_Month'] = pd.to_datetime(dataset3['Year_Month'], format='%Y-%m')

# Now, let's assume we want to merge dataset1 and dataset3 based on 'Year_Month'
# Note: This step assumes both datasets have a 'Year_Month' column in datetime format
merged_dataset = pd.merge(dataset1, dataset3, on='Year_Month', how='inner')

correlation_matrix = merged_dataset[['Consumption(million gallons)', 'Value']].corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Precipitation and Fuel Consumption')
plt.show()

# %% [markdown]
# Based on the heatmap provided, the correlation coefficient between precipitation (Value) and fuel consumption (Consumption in million gallons) is approximately 0.23.
# A correlation coefficient of 0.23 indicates a weak positive linear relationship between precipitation and fuel consumption. This suggests that there might be a slight tendency for fuel consumption to increase as precipitation increases, but the relationship is not strong. With such a weak correlation, we can say that precipitation alone is not a strong predictor of fuel consumption. It is likely that other factors have a more significant impact on fuel consumption than precipitation does. Future research initiatives should focus on correlation of weather and fuel consumption in more extreme weather conditions since normal levels of rain do not have a significant impact on fuel consumption. However, in extreme weather cases, flights often will be delayed for safety reasons. A potential further area of research could then be on ticket price and fuel consumption fluctuation during the El nino years in particular. From the data we have seen so far, however, rain is not a strong contributor to fuel usage.

# %%
plt.figure(figsize=(12, 8))
sns.regplot(x='Value', y='Consumption(million gallons)', data=merged_dataset)
plt.title('Scatter Plot with Regression Line: Precipitation vs. Fuel Consumption')
plt.xlabel('Average Precipitation (inches)')
plt.ylabel('Fuel Consumption (million gallons)')
plt.show()

# %% [markdown]
# The scatter plot above illustrates the relationship between average precipitation (in inches) and fuel consumption (in million gallons). By incorporating a regression line, we aim to quantify the linear relationship between these two variables. While the plot indicates a certain level of positive association—meaning that fuel consumption seems to increase with rising precipitation levels—the dispersion of data points also suggests that this relationship is not very tight. This further supports our earlier conclusion based on the correlation coefficient analysis, indicating a weak positive relationship between precipitation and fuel consumption. However, precipitation alone is not a strong predictor of fuel consumption. This might imply that other, more significant factors are at play in influencing fuel consumption.

# %% [markdown]
# ## Question Part 2: Fuel Consumption & Ticket Prices

# %% [markdown]
# The second part of our research question asks whether there is a relationship between fuel consumption and ticket prices in the U.S. over the last 10 years.
#
# We also explored the relationship between fuel price and ticket price, since we began to think there might be a significant relationship here as well. We decided to plot the data on the same graph to help visualize their relationship.

# %%
# Summarizing key trends for Dataset 1: Fuel Consumption and Cost
fuel_consumption_summary = dataset1.groupby('Year').agg({
    'Consumption(million gallons)': 'sum',
    'Cost(million dollars)': 'sum',
    'Cost per Gallon (dollars)': 'mean'
}).reset_index()

# Correcting column names for Dataset 2 and summarizing ticket prices
ticket_prices_summary = dataset2.groupby('Year').agg({
    'U.S. Average (Current $) ': 'mean',  # Corrected column name
    'U.S. Average (Inflation-Adjusted $) ': 'mean'  # Corrected column name
}).reset_index()

common_years = set(fuel_consumption_summary['Year']).intersection(set(ticket_prices_summary['Year']))
fuel_summary_aligned = fuel_consumption_summary[fuel_consumption_summary['Year'].isin(common_years)]
ticket_prices_aligned = ticket_prices_summary[ticket_prices_summary['Year'].isin(common_years)]

comparison_data = pd.merge(fuel_summary_aligned, ticket_prices_aligned, on='Year', how='inner')

# Plotting
fig, ax1 = plt.subplots(figsize=(14, 8))

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Fuel Cost per Gallon (dollars)', color=color)
ax1.plot(comparison_data['Year'], comparison_data['Cost per Gallon (dollars)'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('U.S. Average Ticket Price (Inflation-Adjusted $)', color=color)  # we already handled the x-label with ax1
ax2.plot(comparison_data['Year'], comparison_data['U.S. Average (Inflation-Adjusted $) '], color=color)
ax2.tick_params(axis='y', labelcolor=color)

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.title('Fuel Cost Influences U.S. Average Ticket Price')
plt.show()

# %% [markdown]
# Initially, there appears to be an inverse relationship, as the cost per gallon of fuel (shown on the left y-axis) decreases and the average ticket price (shown on the right y-axis) increases. This could suggest that other factors are having a more significant impact on ticket prices than fuel costs alone during this period. Around 2020, there is a noticeable sharp decline in both fuel cost and ticket price, which then recover sharply. This synchronized movement post-2020 suggests a positive relationship during this period, likely influenced by external events (e.g., the COVID-19 pandemic) that simultaneously impacted fuel prices and ticket prices. After the 2020 decline, the rebound in both fuel costs and ticket prices indicates a positive relationship, where increases in fuel costs are accompanied by increases in ticket prices. This suggests that during the recovery phase, fuel costs may have had a more direct impact on ticket prices. Considering the entire timeline, the relationship between fuel costs and ticket prices does not appear to be consistently positive. While the post-2020 recovery phase shows a positive relationship, the pre-2020 trend suggests that ticket prices may be influenced by a complex set of factors, of which fuel is only one part. In particular, during 2022 there was a sharp increase in cost per gallon prices in 2022 in both fuel consumption and ticket prices, but the rate of increase was smaller in ticket prices. This suggests that ticket prices do not increase at the same rate that cost per gallon does.

# %% [markdown]
# Next, we wanted to quantify the correlation between fuel consumption and average ticket price, so we created a heatmap with the two variables.

# %%
correlation_matrix_2 = comparison_data[['Consumption(million gallons)', 'U.S. Average (Inflation-Adjusted $) ']].corr()
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix_2, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation between Total Fuel Consumption and Average Ticket Price')
plt.show()

# %% [markdown]
# The heatmap displays a correlation coefficient of 0.38, indicating a moderate positive relationship between total fuel consumption (Consumption(million gallons)) and average ticket price (U.S. Average (Inflation-Adjusted $)). This moderate positive correlation (coefficient of 0.38) suggests that as fuel consumption increases, the average price of airplane tickets also tends to rise. However, this relationship is not very strong, like we concluded above, indicating that there are likely other factors influencing ticket prices, with fuel consumption being just one of them.

# %% [markdown]
# # Ethics & Privacy

# %% [markdown]
# Since we are looking at airline prices and not individual people, it is not necessary for data used to be anonymized to protect individual privacy. The data is available via government agencies, and it is all averages aggregated across large numbers of airlines, which effectively protects the privacy of any individual or organization. Our data comes from the National Oceanic and Atmospheric Administration and the U.S. Department of Transportation, helping us ensure that our sources are clear, traceable, and publicly available ensuring transparency in the research process for peer review.
#
# One potential issue of our analysis is that it is not location-specific since our data covers the entire country, and much can vary at specific airports depending on their resources and geographies. As we analyze, we are aware that the trends can only be indicative of large-scale patterns and will not be sufficient to support extreme changes at any specific airport.

# %% [markdown]
# # Discusison and Conclusion
#
# #### Background, research questions, and hypothesis
#
# At the outset of our project, we were interested in plane tickets and how precipitation and fuel consumption might affect prices. Air travel is a huge economy, and as climate change continues to develop, it becomes ever more important to understand how to minimize the environmental impact of such industries. One way to approach this problem is by examining fuel efficiency and the conditions that cause more or less fuel consumption. We decided to investigate whether there was a relationship between precipitation and airline fuel consumption, and whether there was a relationship between fuel consumption and ticket prices, all in the United States over the last 10 years. We hypothesized that higher precipitation would lead to increased fuel consumption, and that increased fuel consumption would lead to higher ticket prices.
#
# #### Dataset descriptions
#
# We found three datasets to help us answer our two main research questions:
#
# * Dataset 1, from the U.S. Department of Transportation, included monthly data on how much fuel cost per gallon at the time and how many total gallons of fuel were consumed that month.
#
# * Dataset 2, also from the U.S. Department of Transportation, included quarterly data on the average airline fare of domestic flights in the U.S., adjusted for inflation.
#
# * Dataset 3, from the National Oceanic and Atmospheric Administration, included monthly data on average precipitation across the contiguous U.S.
#
# We used Datasets 3 and 1 to answer the first part of our research question regarding the relationship between average precipitation and average fuel consumption. Datasets 2 and 1 helped us address the second part of our question, which involved the relationship between fuel consumption and ticket prices of domestic U.S. commercial flights.
#
# #### Conclusion for Question Part 1
#
# The first part of our research question asked whether precipitation and fuel consumption had a significant relationship. However, our analysis demonstrated only a slight positive correlation (r = 0.23) between average precipitation and total fuel consumption for the United States over the last 10 years. We conclude that precipitation is not a significant predictor of airline fuel consumption, and that other factors are likely more influential in determining fuel consumption. We would ultimately be interested in understanding how fuel consumption varies between identical flights in different weather conditions, but were unable to find data at this granularity. This is an area for potential future research.
#
# #### Conclusion for Question Part 2
#
# The second part of our research question asked whether fuel consumption and ticket price had a significant relationship. Our analysis showed a moderate positive correlation (r = 0.38) between total fuel consumption and average ticket price in the United States for domestic flights in the last 10 years. We conclude that fuel consumption is one of many factors that influences ticket price, but that the process for determining ticket price is ultimately complex. We also recognize that there may be a confounder as the strength of the economy, or the relative popularity of air travel, could explain a common increase in ticket price and total fuel consumption. It makes sense that if more people are travelling, ticket prices would go up, as would fuel consumption. Again, in order to properly answer this question, we would need more specific data that controls for these variables so we could properly compare the fuel consumption and ticket prices of otherwise identical flights.
#
# #### Limitations
#
# The study has several limitations that should be noted. First, the datasets used represent national averages, which may mask regional variations in precipitation, fuel consumption, and ticket prices. Second, the study assumes a direct relationship between the examined variables, not accounting for other potential influencing factors like economic conditions, airline policies, or technological advancements in aircraft efficiency. Additionally, the analysis is limited to a 10-year period, which may not capture longer-term trends or cyclical patterns in the aviation industry. Lastly, the impact of extraordinary events, such as the COVID-19 pandemic, on the aviation sector introduces anomalies that could skew the interpretation of trends and correlations observed in the data.
#
# #### Final conclusion and future steps
#
# Overall, this analysis illustrated the complexity of ticket prices and the airline economy. Airlines use a wide variety of variables and techniques when setting their ticket prices, and it is not a simple equation to predict. However, we did identify a relationship between fuel consumption and ticket prices, implying that fuel consumption is one of many factors that is taken into account when setting ticket prices. We also discovered a potential relationship between fuel cost and ticket price, which would be logical due to the importance of fuel cost on the overall operating costs of arilines.
#
# We were unable to identify a significant relationship between precipitation and fuel consumption. While it is possible that precipitation just doesn't significantly influence ticket prices, it is also possible that the large scale of our analysis masked any regional trends, as mentioned earlier. Future research might look into more local data, to see if there are any identifiable trends at a smaller geographical scale. Another avenue for research could be the influence of other extreme weather patterns on fuel consumption, such as wind, snow, or temperature. If anything, ticket prices might be influenced by flight cancellations and scheduling complexity caused by extreme weather events, but this warrants further investigation.

# %% [markdown]
# # Team Contributions
#
# * **Chuan Peng** - Hypothesis, Abstract, Cleaning and visualizing the raw datasets, Two plots in question part 1 and 2, Final project video
# * **Risa Sundu** - Research Question, Data Overview, EDA for Datasets 1, 2, and 3, Ethics & Privacy, Discussion & Conclusion
# * **Jaeven Tanuwidjaja** - Coding for 2 plots for question part 1 and 2, writing the conclusions for question 1 and 2, team expectations, final project video, further cleaning the datasets to fit plots for question part 1 and 2
# * **Kunnam Kim** - Background, cleaning code, EDA for Datasets 1,2,and 3, video, code cleaning, time line, Team expectations
# * **Maya Buchwald** - Background research and writing, EDA for Datasets 1 and 2, analysis in question part 1&2, video
